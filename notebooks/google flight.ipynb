# %%
departure = "#sb_ifc50"

# %%
from  selenium import webdriver
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-221874091c2c> in <module>
# ----> 1 from  selenium import webdriver
#
# ModuleNotFoundError: No module named 'selenium'

# %%
! conda env list
# Out:
# # conda environments:
# #
# base                  *  C:\Users\NKA\Anaconda3
#                          C:\Users\NKA\miniconda3

# %%
! conda create --name scraping

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.google.com/flights?hl=fr&gl=fr")

# %%
soup = BeautifulSoup(page.text)

# %%
soup.select_one("destination-picker")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...
